# %%
import pandas as pd

# %%
df = pd.read_csv("Sampled_dataMGC.csv")

# %%
df
# Out:
#                DAYTIME  BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV  \
# 0     01-01-2020 00:00                           96.549652
# 1     01-01-2020 12:00                           96.492012
# 2     02-01-2020 00:00                           90.985840
# 3     02-01-2020 12:00                           91.497169
# 4     03-01-2020 00:00                            0.000000
# ...                ...                                 ...
# 2442  06-05-2023 00:00                           78.715469
# 2443  06-05-2023 12:00                           80.735901
# 2444  07-05-2023 00:00                           99.122391
# 2445  07-05-2023 12:00                          101.729347
# 2446  08-05-2023 00:00                           98.841415
#
#       BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV  BBLT_DPP_TRN-1-STG-3-MGC_SUCT-F.PV  \
# 0                              74.596558                           96.837730
# 1                              76.040527                           96.603470
# ...

# %%
df.shape
# Out:
# (2447, 139)

# %%
df.columns
# Out:
# Index(['DAYTIME', 'BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV',
#        'BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV',
#        'BBLT_DPP_TRN-1-STG-3-MGC_SUCT-F.PV',
#        'BBLT_DPP_TRN-1-STG-1-MGC_SUCT-T.PV',
#        'BBLT_DPP_TRN-1-STG-2-MGC_ASV-POS.PV',
#        'BBLT_DPP_TRN-1-STG-2-MGC_DISCH-P.PV',
#        'BBLT_DPP_TRN-1-STG-1-MGC_SUCT-P.PV',
#        'BBLT_DPP_TRN-1-STG-1-MGC_DISCH-P.PV',
#        'BBLT_DPP_TRN-1-STG-1-MGC_DISCH-T.PV',
#        ...
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_SEP-SEAL-GAS-INLET-SDV-CMD.OP',
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_PRIMARY-SEAL-GAS-DE-INLET-MTR-DP.PV',
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_PRIMARY-SEAL-GAS-NDE-INLET-MTR-DP.PV',
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_PRIMARY-SEAL-GAS-DE-VENT-MTR-DP.PV',
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_PRIMARY-SEAL-GAS-NDE-VENT-MTR-DP.PV',
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_SEP-SEAL-GAS-FLTR-DP.PV',
#        'BBLT_DPP_TRN-1-STG-2-3-MGC_SEP-SEAL-GAS-INLET-MTR-DP.PV',
# ...

# %%
df.isnull().sum()
# Out:
# DAYTIME                                                    0
# BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV                         0
# BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV                         0
# BBLT_DPP_TRN-1-STG-3-MGC_SUCT-F.PV                         0
# BBLT_DPP_TRN-1-STG-1-MGC_SUCT-T.PV                         0
#                                                           ..
# BBLT_DPP_TRN-1-STG-2-3-MGC_SEP-SEAL-GAS-FLTR-DP.PV         0
# BBLT_DPP_TRN-1-STG-2-3-MGC_SEP-SEAL-GAS-INLET-MTR-DP.PV    0
# BBLT_DPP_TRN-1-STG-1-MGC_TURBINE-NGP-SPD.PV                0
# BBLT_DPP_TRN-1-STG-1-MGC_TURBINE-NPT-SPD.PV                0
# BBLT_DPP_TRN-1-STG-1-MGC_RUN.PE                            0
# Length: 139, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2447 entries, 0 to 2446
# Columns: 139 entries, DAYTIME to BBLT_DPP_TRN-1-STG-1-MGC_RUN.PE
# dtypes: float64(6), object(133)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#        BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV  BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV  \
# count                         2447.000000                         2447.000000
# mean                            50.232802                           43.949148
# std                             34.763890                           32.739518
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.013170
# 50%                             65.164909                           50.454929
# 75%                             74.231323                           70.886463
# max                            124.999985                           99.998871
#
#        BBLT_DPP_TRN-1-STG-3-MGC_SUCT-F.PV  BBLT_DPP_TRN-1-STG-1-MGC_SUCT-T.PV  \
# count                         2447.000000                         2447.000000
# mean                            68.716784                           93.650537
# ...

# %%
df.corr() > 0.9
# Out:
#                                                     BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV  \
# BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV                                                True
# BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV                                                True
# BBLT_DPP_TRN-1-STG-3-MGC_SUCT-F.PV                                                True
# BBLT_DPP_TRN-1-STG-1-MGC_SUCT-T.PV                                                True
# BBLT_DPP_TRN-1-STG-1-MGC_CTRT-TURBINE-PERFM-FAC...                               False
# BBLT_DPP_TRN-1-STG-1-MGC_TURBINE-T5-T-SPRD.PE                                    False
#
#                                                     BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV  \
# BBLT_DPP_TRN-1-STG-1-MGC_SUCT-F.PV                                                True
# BBLT_DPP_TRN-1-STG-2-MGC_SUCT-F.PV                                                True
# BBLT_DPP_TRN-1-STG-3-MGC_SUCT-F.PV                                                True
# ...
